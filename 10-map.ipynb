# %% [markdown]
# Map
#
# - Função que aplica uma função a todos os itens de um iterável (uma lista, por exemplo).
# - É uma maneira eficiente e consisa de transformar dados.

# %%
def quadrado(x):
    return x ** 2

# %%
numeros = [1, 2, 3, 4, 5]

# %%
for n in numeros:
    print(quadrado(n))
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
resultados = map(quadrado, numeros)
list(resultados)
# Out:
# [1, 4, 9, 16, 25]

# %%
def celsius_para_fahrenheit(c):
    return (c * 1.8) + 32

# %%
temperaturas_celsius = [0, 12, 34, 100]

# %%
temperaturas_fahrenheit = map(celsius_para_fahrenheit, temperaturas_celsius)

print(list(temperaturas_fahrenheit))
# Out:
# [32.0, 53.6, 93.2, 212.0]

# %%
def normalizar_nome(nome):
    return nome.strip().lower()

# %%
nomes =['  João  ', '  MARIA  ', '  Joaquim  ', '  CARLOS  ']

# %%
nomes_normalizados = map(normalizar_nome, nomes)

print(list(nomes_normalizados))
# Out:
# ['joão', 'maria', 'joaquim', 'carlos']
